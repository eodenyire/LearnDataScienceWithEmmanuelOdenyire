# %% [markdown]
# # Capstone Project Template
# ## Learning Objectives
# - Frame a real-world problem as a data science project
# - Complete an end-to-end analysis from data to deployment
# - Present findings professionally

# %%
# ─────────────────────────────────────────────────────
# SECTION 1: PROBLEM DEFINITION
# ─────────────────────────────────────────────────────
project_info = {
    'title': 'Your Project Title Here',
    'problem_statement': 'What problem are you solving?',
    'business_impact': 'Why does this matter?',
    'success_metric': 'How will you measure success?',
    'data_source': 'Where does your data come from?'
}
for k, v in project_info.items():
    print(f'{k:20s}: {v}')

# %%
# ─────────────────────────────────────────────────────
# SECTION 2: DATA COLLECTION & EXPLORATION
# ─────────────────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# df = pd.read_csv('your_data.csv')  # load your data

# EDA checklist
eda_checklist = [
    'df.shape, df.dtypes, df.head()',
    'df.isnull().sum() - check missing values',
    'df.describe() - summary statistics',
    'Distribution plots for numerical features',
    'Value counts for categorical features',
    'Correlation heatmap',
    'Target variable distribution'
]
print('EDA Checklist:')
for item in eda_checklist:
    print(f'  □ {item}')

# %%
# ─────────────────────────────────────────────────────
# SECTION 3: FEATURE ENGINEERING & PREPROCESSING
# ─────────────────────────────────────────────────────
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer

preprocessing_steps = [
    '1. Handle missing values (impute or drop)',
    '2. Encode categorical variables',
    '3. Scale/normalize numerical features',
    '4. Create derived features',
    '5. Handle outliers',
    '6. Feature selection'
]
for step in preprocessing_steps:
    print(step)

# %%
# ─────────────────────────────────────────────────────
# SECTION 4: MODELING
# ─────────────────────────────────────────────────────
from sklearn.model_selection import train_test_split, cross_val_score

# Model comparison framework
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

model_registry = {
    'Baseline (LogReg/LinReg)': 'Simple, interpretable starting point',
    'Random Forest': 'Robust ensemble, handles non-linearity',
    'Gradient Boosting': 'Often best performance on tabular data',
    'Neural Network': 'For complex patterns and large datasets'
}
print('Model Selection Guide:')
for m, desc in model_registry.items():
    print(f'  {m:30s}: {desc}')

# %%
# ─────────────────────────────────────────────────────
# SECTION 5: EVALUATION & INTERPRETATION
# ─────────────────────────────────────────────────────
evaluation_metrics = {
    'Classification': ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC', 'Confusion Matrix'],
    'Regression': ['MAE', 'MSE', 'RMSE', 'R²', 'MAPE'],
    'Clustering': ['Silhouette Score', 'Davies-Bouldin', 'Inertia']
}
for task, metrics in evaluation_metrics.items():
    print(f'{task}: {', '.join(metrics)}')

# %% [markdown]
# ## Project Deliverables
# 1. **Notebook** – Complete, well-documented analysis
# 2. **Presentation** – 10-slide summary for non-technical audience
# 3. **GitHub Repo** – Clean code with README and requirements.txt
# 4. **Demo** (optional) – Deployed Streamlit/FastAPI app

# %% [markdown]
# ## Summary
# Follow this template to build a rigorous, end-to-end data science project.
# Focus on storytelling: every technical decision should connect to the business problem.
