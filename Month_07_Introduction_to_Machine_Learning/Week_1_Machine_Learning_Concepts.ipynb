# %% [markdown]
# # Week 1: Machine Learning Concepts
#
# ## Learning Objectives
# - Understand supervised, unsupervised, and reinforcement learning
# - Learn the ML workflow
# - Use scikit-learn's fit/predict/transform API
# - Understand bias-variance tradeoff

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

sns.set_theme(style='whitegrid')
print('scikit-learn ready')

# %% [markdown]
# ## 1. Types of Machine Learning
#
# **Supervised Learning**: Learn from labelled data
# - Regression: predict continuous values
# - Classification: predict categories
#
# **Unsupervised Learning**: Find patterns in unlabelled data
# - Clustering, Dimensionality Reduction
#
# **Reinforcement Learning**: Learn through trial and error with rewards

# %% [markdown]
# ## 2. The ML Workflow
#
# 1. Define the problem
# 2. Collect and explore data
# 3. Preprocess features
# 4. Split: train/validation/test
# 5. Train model
# 6. Evaluate and tune
# 7. Deploy

# %%
iris = load_iris()
X, y = iris.data, iris.target
print('Features:', iris.feature_names)
print('Classes:', iris.target_names)
print('Shape:', X.shape)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)
print(f'Train: {X_train.shape}, Test: {X_test.shape}')

# %%
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s  = scaler.transform(X_test)
print('Scaled mean:', X_train_s.mean(axis=0).round(3))
print('Scaled std: ', X_train_s.std(axis=0).round(3))

# %% [markdown]
# ## 3. Bias-Variance Tradeoff
#
# - **High Bias (Underfitting)**: Model too simple, misses patterns
# - **High Variance (Overfitting)**: Model memorises training data
# - **Goal**: Find the balance that generalises well

# %%
train_scores, test_scores = [], []
ks = range(1, 31)
for k in ks:
    pipe = Pipeline([('scaler', StandardScaler()),
                     ('knn', KNeighborsClassifier(n_neighbors=k))])
    pipe.fit(X_train, y_train)
    train_scores.append(accuracy_score(y_train, pipe.predict(X_train)))
    test_scores.append(accuracy_score(y_test, pipe.predict(X_test)))

plt.figure(figsize=(8, 4))
plt.plot(ks, train_scores, label='Train')
plt.plot(ks, test_scores,  label='Test')
plt.xlabel('k (n_neighbors)'); plt.ylabel('Accuracy')
plt.title('KNN: Bias-Variance Tradeoff')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Exercise
#
# 1. Load `load_diabetes()` and explore the dataset
# 2. Split 80/20 and scale the features
# 3. Explain whether it is a regression or classification problem

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# This week you learned:
# - ✓ Supervised, unsupervised, and reinforcement learning
# - ✓ End-to-end ML workflow
# - ✓ scikit-learn fit/predict/transform API
# - ✓ Bias-variance tradeoff
#
# ## Next Week
# Regression algorithms!
