# %% [markdown]
# <a href="https://colab.research.google.com/github/eodenyire/LearnDataScienceWithEmmanuelOdenyire/blob/main/Phase_1_Foundations_Python_and_Math/Month_01_Python_Basics/Week_3_Data_Structures/Day_20_Advanced_Python_Patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 20: Advanced Python Patterns for Data Science
#
# **Phase 1 | Month 1 | Week 3 | Bootcamp Day 20**
#
# **Daily Schedule (15 hours):**
# - 🌅 Morning (5h): Concepts & Notebook
# - ☀️ Afternoon (5h): Practice Exercises
# - 🌙 Evening (5h): Projects, Assignments & Quiz Review
#
# ## Learning Objectives
# - Use dataclasses for clean data models
# - Apply type hints
# - Understand comprehension patterns (dict, set comprehensions)
# - Use `*` and `**` unpacking

# %% [markdown]
# ## 🌅 Morning Session — Core Concepts

# %%
from dataclasses import dataclass, field
from typing import List

@dataclass
class DataRecord:
    id: int
    name: str
    values: List[float] = field(default_factory=list)
    
    def mean(self) -> float:
        return sum(self.values) / len(self.values) if self.values else 0.0
    
    def __post_init__(self):
        if not self.name:
            raise ValueError('name cannot be empty')

record = DataRecord(1, 'sales', [10.5, 22.3, 15.8, 30.1])
print(record)
print(f'Mean: {record.mean():.2f}')

# %% [markdown]
# ## 📚 Resources
# - [Python Data Structures](https://docs.python.org/3/tutorial/datastructures.html)
# - [Real Python: Data Structures](https://realpython.com/python-data-structures/)
