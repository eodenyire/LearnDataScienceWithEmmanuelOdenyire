# %% [markdown]
# <a href="https://colab.research.google.com/github/eodenyire/LearnDataScienceWithEmmanuelOdenyire/blob/main/Phase_1_Foundations_Python_and_Math/Month_01_Python_Basics/Week_1_Python_Fundamentals/Day_04_Operators_and_Expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 4: Operators and Expressions
#
# ## Learning Objectives
# - Understand arithmetic, comparison, and logical operators
# - Work with assignment operators
# - Understand operator precedence
# - Build expressions and evaluate them

# %% [markdown]
# ## 1. Arithmetic Operators
#
# Arithmetic operators perform mathematical calculations:

# %%
a = 20
b = 7

print(f'Addition:       {a} + {b} = {a + b}')
print(f'Subtraction:    {a} - {b} = {a - b}')
print(f'Multiplication: {a} * {b} = {a * b}')
print(f'Division:       {a} / {b} = {a / b:.4f}')
print(f'Floor Division: {a} // {b} = {a // b}')
print(f'Modulus:        {a} % {b} = {a % b}')
print(f'Exponentiation: {a} ** {b} = {a ** b}')

# %% [markdown]
# ## 2. Comparison Operators
#
# Comparison operators return `True` or `False`:

# %%
x = 10
y = 15

print(f'{x} == {y}: {x == y}')  # Equal
print(f'{x} != {y}: {x != y}')  # Not equal
print(f'{x} < {y}:  {x < y}')   # Less than
print(f'{x} > {y}:  {x > y}')   # Greater than
print(f'{x} <= {y}: {x <= y}')  # Less or equal
print(f'{x} >= {y}: {x >= y}')  # Greater or equal

# %% [markdown]
# ## 3. Logical Operators
#
# `and`, `or`, `not` combine boolean expressions:

# %%
is_adult = True
has_ticket = False

print(f'is_adult AND has_ticket: {is_adult and has_ticket}')
print(f'is_adult OR  has_ticket: {is_adult or has_ticket}')
print(f'NOT is_adult:            {not is_adult}')

# Compound conditions
age = 20
score = 85
print(f'Age >= 18 and score >= 80: {age >= 18 and score >= 80}')

# %% [markdown]
# ## 4. Assignment Operators

# %%
n = 100
print(f'Start: n = {n}')

n += 10;  print(f'n += 10  -> {n}')
n -= 5;   print(f'n -= 5   -> {n}')
n *= 2;   print(f'n *= 2   -> {n}')
n //= 3;  print(f'n //= 3  -> {n}')
n %= 7;   print(f'n %= 7   -> {n}')
n **= 2;  print(f'n **= 2  -> {n}')

# %% [markdown]
# ## 5. Operator Precedence (PEMDAS / BODMAS)
#
# Python follows standard mathematical precedence:
# 1. Parentheses `()`
# 2. Exponentiation `**`
# 3. Multiplication / Division `*`, `/`, `//`, `%`
# 4. Addition / Subtraction `+`, `-`

# %%
# Without parentheses
result1 = 2 + 3 * 4
print(f'2 + 3 * 4 = {result1}')  # 14, not 20

# With parentheses
result2 = (2 + 3) * 4
print(f'(2 + 3) * 4 = {result2}')  # 20

# Complex expression
result3 = 2 ** 3 + 10 // 3 - 1
print(f'2 ** 3 + 10 // 3 - 1 = {result3}')

# %% [markdown]
# ## Exercise
#
# 1. Calculate the area and perimeter of a rectangle with length=12 and width=7
# 2. Use comparison operators to check if a temperature (37.5) indicates fever (> 37.0)
# 3. Check if a number is both positive AND even

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Today you learned:
# - ✓ Arithmetic operators (+, -, *, /, //, %, **)
# - ✓ Comparison operators (==, !=, <, >, <=, >=)
# - ✓ Logical operators (and, or, not)
# - ✓ Assignment operators (+=, -=, *=, etc.)
# - ✓ Operator precedence
#
# ## Next Steps
# Next, we'll learn about control flow: if statements, loops, and functions!
