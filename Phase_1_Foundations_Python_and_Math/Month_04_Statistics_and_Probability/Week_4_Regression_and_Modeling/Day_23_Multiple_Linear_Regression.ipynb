# %% [markdown]
# <a href="https://colab.research.google.com/github/eodenyire/LearnDataScienceWithEmmanuelOdenyire/blob/main/Phase_1_Foundations_Python_and_Math/Month_04_Statistics_and_Probability/Week_4_Regression_and_Modeling/Day_23_Multiple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# <img src="https://github.com/user-attachments/assets/2a4adf95-3d28-41e2-90d0-d06b2e9c8fa3" alt="Learn Data Science with Emmanuel Odenyire" width="180"/>

# %% [markdown]
# # Day 23: Multiple Linear Regression
#
# ## Phase 1 | Month 4 | Week 4 | Day 23
#
# **🎯 Goal:** Extend regression to multiple predictors and understand adjusted R², multicollinearity, and feature selection.
# **⏱️ Study Session:** ~2 hours

# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

np.random.seed(42)
n = 300

# Predicting house price in Nairobi (KES millions)
bedrooms  = np.random.randint(1, 6, n)
floor_m2  = np.random.normal(120, 45, n).clip(30, 350)
dist_cbd  = np.random.uniform(1, 30, n)    # km from CBD
noise     = np.random.normal(0, 1.5, n)

price = (1.5
         + 0.8 * bedrooms
         + 0.05 * floor_m2
         - 0.12 * dist_cbd
         + noise)

df = pd.DataFrame({'price_m':price,'bedrooms':bedrooms,'floor_m2':floor_m2,'dist_cbd_km':dist_cbd})

X = sm.add_constant(df[['bedrooms','floor_m2','dist_cbd_km']])
model = sm.OLS(df['price_m'], X).fit()
print(model.summary())

# %% [markdown]
# ## Interpreting Multiple Regression Output
#
# - **Coefficients**: partial effect of each variable holding others constant
# - **Adj. R²**: R² penalised for adding irrelevant predictors
# - **p-values**: test whether each coefficient ≠ 0
# - **VIF > 5**: warns of multicollinearity

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

np.random.seed(42)
n = 300
bedrooms = np.random.randint(1, 6, n)
floor_m2 = np.random.normal(120, 45, n).clip(30, 350)
dist_cbd = np.random.uniform(1, 30, n)
price = 1.5 + 0.8*bedrooms + 0.05*floor_m2 - 0.12*dist_cbd + np.random.normal(0,1.5,n)

X_df = pd.DataFrame({'const':1,'bedrooms':bedrooms,'floor_m2':floor_m2,'dist_cbd_km':dist_cbd})
vif = pd.DataFrame()
vif['Feature'] = X_df.columns
vif['VIF'] = [variance_inflation_factor(X_df.values, i) for i in range(X_df.shape[1])]
print('Variance Inflation Factors:')
print(vif)

# %% [markdown]
# ## 💪 Exercises
#
# ### Exercise 1
# Add a new variable `age_years` (house age) to the Nairobi house price model. Does it improve Adj. R²?
#
# ### Exercise 2
# Fit a model predicting M-Pesa transaction amount from: hour_of_day, is_weekend, user_tenure_months. Interpret each coefficient.

# %%
# Your code here

# %% [markdown]
# ## 📋 Summary
#
# - ✓ MLR: ŷ = β₀ + β₁x₁ + β₂x₂ + ... + βₖxₖ
# - ✓ Use Adj. R² (not R²) when comparing models with different numbers of predictors
# - ✓ Check VIF for multicollinearity
# - ✓ `statsmodels.OLS` provides full statistical output
#
# ## 🚀 Next Steps
# **Day 24: Regression Diagnostics and Assumptions**
